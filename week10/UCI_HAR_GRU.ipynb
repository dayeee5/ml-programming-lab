# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split,  StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense, Flatten,
    Conv1D, MaxPooling1D,
    LSTM, GRU,
    Dropout, BatchNormalization
)

# %%
# -----------------------------
# 1) 파일 로드 함수 정의
# -----------------------------

def load_file(filepath):
    """공백(whitespace)으로 구분된 txt 파일을 읽어서 numpy 배열로 변환"""
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

def load_group(filenames, prefix=''):
    """여러 센서 파일을 불러와서 (샘플, 타임스텝, 특성) 형태의 3D 배열로 결합"""
    loaded = []
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    loaded = np.dstack(loaded)
    return loaded

def load_dataset_group(group, prefix=''):
    """train/test 그룹별로 9개 센서 신호 + 라벨 로드"""
    filepath = prefix + '/' + group + '/Inertial Signals/'

    filenames = []
    # 총가속도
    filenames += ['total_acc_x_' + group + '.txt',
                  'total_acc_y_' + group + '.txt',
                  'total_acc_z_' + group + '.txt']
    # 신체가속도
    filenames += ['body_acc_x_' + group + '.txt',
                  'body_acc_y_' + group + '.txt',
                  'body_acc_z_' + group + '.txt']
    # 자이로스코프
    filenames += ['body_gyro_x_' + group + '.txt',
                  'body_gyro_y_' + group + '.txt',
                  'body_gyro_z_' + group + '.txt']

    X = load_group(filenames, filepath)
    y = load_file(prefix + '/' + group + '/y_' + group + '.txt')
    return X, y

# %%
def load_dataset(prefix=''):
    """전체 train / test 데이터셋 로드 + 원-핫 인코딩"""
    base_path = prefix + '/content/drive/MyDrive/ml-programming-lab/week10/UCI HAR Dataset'

    trainX, trainy = load_dataset_group('train', base_path)
    testX, testy = load_dataset_group('test', base_path)

    # 라벨을 0 ~ 5로 맞추기 (원래 1~6)
    trainy = trainy - 1
    testy = testy - 1

    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)

    print("trainX:", trainX.shape,
          "trainy:", trainy.shape,
          "trainy_one_hot:", trainy_one_hot.shape)
    print("testX:", testX.shape,
          "testy:", testy.shape,
          "testy_one_hot:", testy_one_hot.shape)

    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %%
# -----------------------------
# 2) 데이터 로드 + 스케일링
# -----------------------------

trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset(prefix='')

print(f"원본 trainX shape: {trainX.shape}, testX shape: {testX.shape}")

# --- 스케일링 ---
scaler = StandardScaler()
trainX_reshaped = trainX.reshape((trainX.shape[0], -1))
testX_reshaped  = testX.reshape((testX.shape[0], -1))
trainX_scaled = scaler.fit_transform(trainX_reshaped).reshape(trainX.shape)
testX_scaled  = scaler.transform(testX_reshaped).reshape(testX.shape)

# --- Train / Validation Split ---
X_train, X_val, y_train_one_hot, y_val_one_hot, y_train, y_val = train_test_split(
    trainX_scaled, trainy_one_hot, trainy, test_size=0.2, random_state=100
)
# Out:
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# trainX: (7352, 128, 9) trainy: (7352, 1) trainy_one_hot: (7352, 6)
# testX: (2947, 128, 9) testy: (2947, 1) testy_one_hot: (2947, 6)
# 원본 trainX shape: (7352, 128, 9), testX shape: (2947, 128, 9)

# %%
# -----------------------------
# 3) 입력 차원 및 클래스 개수 설정
# -----------------------------

n_timesteps = X_train.shape[1]
n_features  = X_train.shape[2]
n_outputs   = y_train_one_hot.shape[1]

print("n_timesteps:", n_timesteps)
print("n_features :", n_features)
print("n_outputs  :", n_outputs)
# Out:
# n_timesteps: 128
# n_features : 9
# n_outputs  : 6

# %%
# -----------------------------
# 4) GRU 모델 정의 및 학습
# -----------------------------

# 모델 정의
gru_model = Sequential([
    GRU(256, return_sequences=True, input_shape=(n_timesteps, n_features)),
    Dropout(0.3),
    GRU(128),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.4),
    Dense(n_outputs, activation='softmax')
])

# 모델 컴파일
gru_model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# 모델 구조 요약
gru_model.summary()

# 모델 학습
history_gru = gru_model.fit(
    X_train, y_train_one_hot,
    epochs=100,
    batch_size=64,
    validation_data=(X_val, y_val_one_hot),
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 128, 256)       │       205,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 128)            │       148,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 370,566 (1.41 MB)
#  Trainable params: 370,566 (1.41 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.5413 - loss: 1.1735 - val_accuracy: 0.8953 - val_loss: 0.2706
# Epoch 2/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9096 - loss: 0.2612 - val_accuracy: 0.8994 - val_loss: 0.2452
# Epoch 3/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9195 - loss: 0.2124 - val_accuracy: 0.9422 - val_loss: 0.1249
# Epoch 4/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9470 - loss: 0.1378 - val_accuracy: 0.9361 - val_loss: 0.1295
# Epoch 5/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9503 - loss: 0.1208 - val_accuracy: 0.9415 - val_loss: 0.1214
# Epoch 6/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9476 - loss: 0.1406 - val_accuracy: 0.9497 - val_loss: 0.1262
# Epoch 7/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9575 - loss: 0.1186 - val_accuracy: 0.9402 - val_loss: 0.1220
# Epoch 8/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9464 - loss: 0.1159 - val_accuracy: 0.9483 - val_loss: 0.1207
# Epoch 9/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9574 - loss: 0.1141 - val_accuracy: 0.9497 - val_loss: 0.1177
# Epoch 10/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9463 - loss: 0.1110 - val_accuracy: 0.9517 - val_loss: 0.1386
# Epoch 11/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9458 - loss: 0.1286 - val_accuracy: 0.9538 - val_loss: 0.1139
# Epoch 12/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9590 - loss: 0.1128 - val_accuracy: 0.9497 - val_loss: 0.1125
# Epoch 13/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9575 - loss: 0.1078 - val_accuracy: 0.9511 - val_loss: 0.1094
# Epoch 14/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9543 - loss: 0.1118 - val_accuracy: 0.9511 - val_loss: 0.1142
# Epoch 15/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9630 - loss: 0.0954 - val_accuracy: 0.9565 - val_loss: 0.1167
# Epoch 16/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9628 - loss: 0.0966 - val_accuracy: 0.9517 - val_loss: 0.1185
# Epoch 17/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9546 - loss: 0.1023 - val_accuracy: 0.9490 - val_loss: 0.1210
# Epoch 18/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9517 - loss: 0.1121 - val_accuracy: 0.9558 - val_loss: 0.1115
# Epoch 19/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9590 - loss: 0.1040 - val_accuracy: 0.9524 - val_loss: 0.1133
# Epoch 20/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9559 - loss: 0.1000 - val_accuracy: 0.9470 - val_loss: 0.1270
# Epoch 21/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9394 - loss: 0.1722 - val_accuracy: 0.9470 - val_loss: 0.1191
# Epoch 22/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9591 - loss: 0.1019 - val_accuracy: 0.9524 - val_loss: 0.1159
# Epoch 23/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9616 - loss: 0.0980 - val_accuracy: 0.9504 - val_loss: 0.1136
# Epoch 24/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9563 - loss: 0.1021 - val_accuracy: 0.9490 - val_loss: 0.1128
# Epoch 25/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9510 - loss: 0.1251 - val_accuracy: 0.9483 - val_loss: 0.1207
# Epoch 26/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9498 - loss: 0.1161 - val_accuracy: 0.9511 - val_loss: 0.1186
# Epoch 27/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9606 - loss: 0.0966 - val_accuracy: 0.9504 - val_loss: 0.1136
# Epoch 28/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9579 - loss: 0.1030 - val_accuracy: 0.9524 - val_loss: 0.1073
# Epoch 29/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9616 - loss: 0.0994 - val_accuracy: 0.9538 - val_loss: 0.1076
# Epoch 30/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9625 - loss: 0.1009 - val_accuracy: 0.9524 - val_loss: 0.1098
# Epoch 31/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9587 - loss: 0.0990 - val_accuracy: 0.9517 - val_loss: 0.1084
# Epoch 32/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9647 - loss: 0.0973 - val_accuracy: 0.9517 - val_loss: 0.1040
# Epoch 33/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9585 - loss: 0.0919 - val_accuracy: 0.9470 - val_loss: 0.1407
# Epoch 34/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9563 - loss: 0.1054 - val_accuracy: 0.9395 - val_loss: 0.1173
# Epoch 35/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9551 - loss: 0.0926 - val_accuracy: 0.9538 - val_loss: 0.0987
# Epoch 36/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9580 - loss: 0.0925 - val_accuracy: 0.9551 - val_loss: 0.1087
# Epoch 37/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9560 - loss: 0.1043 - val_accuracy: 0.9545 - val_loss: 0.1035
# Epoch 38/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9604 - loss: 0.0932 - val_accuracy: 0.9449 - val_loss: 0.1215
# Epoch 39/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9590 - loss: 0.0863 - val_accuracy: 0.9517 - val_loss: 0.1034
# Epoch 40/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9602 - loss: 0.0933 - val_accuracy: 0.9422 - val_loss: 0.1727
# Epoch 41/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9544 - loss: 0.1135 - val_accuracy: 0.9551 - val_loss: 0.1001
# Epoch 42/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9599 - loss: 0.0948 - val_accuracy: 0.9545 - val_loss: 0.1032
# Epoch 43/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9637 - loss: 0.0932 - val_accuracy: 0.9558 - val_loss: 0.1010
# Epoch 44/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9629 - loss: 0.0875 - val_accuracy: 0.9579 - val_loss: 0.0915
# Epoch 45/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9625 - loss: 0.0888 - val_accuracy: 0.9524 - val_loss: 0.0977
# Epoch 46/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9633 - loss: 0.0865 - val_accuracy: 0.9585 - val_loss: 0.0943
# Epoch 47/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9667 - loss: 0.0811 - val_accuracy: 0.9490 - val_loss: 0.1105
# Epoch 48/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9600 - loss: 0.0950 - val_accuracy: 0.9585 - val_loss: 0.0950
# Epoch 49/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9540 - loss: 0.0973 - val_accuracy: 0.9558 - val_loss: 0.0896
# Epoch 50/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9639 - loss: 0.0859 - val_accuracy: 0.9592 - val_loss: 0.0925
# Epoch 51/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9683 - loss: 0.0758 - val_accuracy: 0.9551 - val_loss: 0.1019
# Epoch 52/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9530 - loss: 0.1097 - val_accuracy: 0.9545 - val_loss: 0.1027
# Epoch 53/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9575 - loss: 0.1050 - val_accuracy: 0.9558 - val_loss: 0.0955
# Epoch 54/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9607 - loss: 0.0880 - val_accuracy: 0.9606 - val_loss: 0.0934
# Epoch 55/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9639 - loss: 0.0848 - val_accuracy: 0.9579 - val_loss: 0.0984
# Epoch 56/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9684 - loss: 0.0853 - val_accuracy: 0.9619 - val_loss: 0.1107
# Epoch 57/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9606 - loss: 0.0898 - val_accuracy: 0.9619 - val_loss: 0.0892
# Epoch 58/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9683 - loss: 0.0789 - val_accuracy: 0.9640 - val_loss: 0.0937
# Epoch 59/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9679 - loss: 0.0829 - val_accuracy: 0.9585 - val_loss: 0.1138
# Epoch 60/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9700 - loss: 0.0791 - val_accuracy: 0.9613 - val_loss: 0.0852
# Epoch 61/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9720 - loss: 0.0734 - val_accuracy: 0.9633 - val_loss: 0.0781
# Epoch 62/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9708 - loss: 0.0750 - val_accuracy: 0.9653 - val_loss: 0.0783
# Epoch 63/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9766 - loss: 0.0586 - val_accuracy: 0.9714 - val_loss: 0.0730
# Epoch 64/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9763 - loss: 0.0673 - val_accuracy: 0.9646 - val_loss: 0.0833
# Epoch 65/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9778 - loss: 0.0672 - val_accuracy: 0.9511 - val_loss: 0.0977
# Epoch 66/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9684 - loss: 0.0730 - val_accuracy: 0.9728 - val_loss: 0.0687
# Epoch 67/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9803 - loss: 0.0528 - val_accuracy: 0.9680 - val_loss: 0.0660
# Epoch 68/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9782 - loss: 0.0544 - val_accuracy: 0.9735 - val_loss: 0.0574
# Epoch 69/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9784 - loss: 0.0585 - val_accuracy: 0.9674 - val_loss: 0.0937
# Epoch 70/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9701 - loss: 0.0719 - val_accuracy: 0.9687 - val_loss: 0.0743
# Epoch 71/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9769 - loss: 0.0578 - val_accuracy: 0.9755 - val_loss: 0.0618
# Epoch 72/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9798 - loss: 0.0465 - val_accuracy: 0.9789 - val_loss: 0.0439
# Epoch 73/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9742 - loss: 0.0571 - val_accuracy: 0.9748 - val_loss: 0.0522
# Epoch 74/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9828 - loss: 0.0380 - val_accuracy: 0.9735 - val_loss: 0.0570
# Epoch 75/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9861 - loss: 0.0376 - val_accuracy: 0.9694 - val_loss: 0.0737
# Epoch 76/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9804 - loss: 0.0452 - val_accuracy: 0.9626 - val_loss: 0.0702
# Epoch 77/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9829 - loss: 0.0415 - val_accuracy: 0.9782 - val_loss: 0.0636
# Epoch 78/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9874 - loss: 0.0314 - val_accuracy: 0.9844 - val_loss: 0.0466
# Epoch 79/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9913 - loss: 0.0232 - val_accuracy: 0.9850 - val_loss: 0.0393
# Epoch 80/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9891 - loss: 0.0277 - val_accuracy: 0.9776 - val_loss: 0.0502
# Epoch 81/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9888 - loss: 0.0289 - val_accuracy: 0.9653 - val_loss: 0.0788
# Epoch 82/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9849 - loss: 0.0333 - val_accuracy: 0.9850 - val_loss: 0.0389
# Epoch 83/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9876 - loss: 0.0342 - val_accuracy: 0.9857 - val_loss: 0.0391
# Epoch 84/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9952 - loss: 0.0156 - val_accuracy: 0.9816 - val_loss: 0.0570
# Epoch 85/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9916 - loss: 0.0224 - val_accuracy: 0.9782 - val_loss: 0.0794
# Epoch 86/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9940 - loss: 0.0202 - val_accuracy: 0.9823 - val_loss: 0.0442
# Epoch 87/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9907 - loss: 0.0281 - val_accuracy: 0.9850 - val_loss: 0.0400
# Epoch 88/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9911 - loss: 0.0254 - val_accuracy: 0.9878 - val_loss: 0.0486
# Epoch 89/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9916 - loss: 0.0226 - val_accuracy: 0.9878 - val_loss: 0.0399
# Epoch 90/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9970 - loss: 0.0101 - val_accuracy: 0.9898 - val_loss: 0.0425
# Epoch 91/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9954 - loss: 0.0147 - val_accuracy: 0.9782 - val_loss: 0.0847
# Epoch 92/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9904 - loss: 0.0294 - val_accuracy: 0.9884 - val_loss: 0.0394
# Epoch 93/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9921 - loss: 0.0304 - val_accuracy: 0.9755 - val_loss: 0.1295
# Epoch 94/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9819 - loss: 0.0599 - val_accuracy: 0.9891 - val_loss: 0.0337
# Epoch 95/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9938 - loss: 0.0189 - val_accuracy: 0.9878 - val_loss: 0.0421
# Epoch 96/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9931 - loss: 0.0196 - val_accuracy: 0.9864 - val_loss: 0.0491
# Epoch 97/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9959 - loss: 0.0131 - val_accuracy: 0.9912 - val_loss: 0.0315
# Epoch 98/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9964 - loss: 0.0133 - val_accuracy: 0.9898 - val_loss: 0.0326
# Epoch 99/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9991 - loss: 0.0042 - val_accuracy: 0.9898 - val_loss: 0.0320
# Epoch 100/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9981 - loss: 0.0079 - val_accuracy: 0.9776 - val_loss: 0.0701

# %%
# -----------------------------
# 5) 학습 곡선 시각화
# -----------------------------

# 학습 손실 곡선
loss = history_gru.history['loss']
val_loss = history_gru.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation Loss - GRU')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 학습 정확도 곡선
acc = history_gru.history['accuracy']
val_acc = history_gru.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and Validation Accuracy - GRU')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# -----------------------------
# 6) 모델 평가
# -----------------------------

# 테스트 데이터 예측
pred = gru_model.predict(testX_scaled)
pred = np.argmax(pred, axis=-1)

# 혼동 행렬 및 정확도 출력
cm = confusion_matrix(testy, pred)
print("Confusion Matrix:\n", cm)
print("\nAccuracy:", accuracy_score(testy, pred))
print("\nClassification Report:\n", classification_report(testy, pred))

# 혼동 행렬 시각화
sns.heatmap(cm, annot=True, fmt='.2f', cmap='magma')
plt.title('Confusion Matrix - GRU')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Confusion Matrix:
#  [[466   4  26   0   0   0]
#  [  5 449  17   0   0   0]
#  [  7   2 410   1   0   0]
#  [  0   2   0 398  70  21]
#  [  0   0   0  18 514   0]
#  [  0   0   0   0   0 537]]
#
# Accuracy: 0.9412962334577536
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       496
#            1       0.98      0.95      0.97       471
#            2       0.91      0.98      0.94       420
#            3       0.95      0.81      0.88       491
#            4       0.88      0.97      0.92       532
#            5       0.96      1.00      0.98       537
#
#     accuracy                           0.94      2947
#    macro avg       0.94      0.94      0.94      2947
# weighted avg       0.94      0.94      0.94      2947

# %%
# -----------------------------
# 7) 5-Fold 교차 검증
# -----------------------------

print("\n===== 5-Fold Cross Validation (GRU) =====")

X_all = trainX_scaled
y_all_int = trainy.flatten()
y_all_one_hot = trainy_one_hot

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

def create_gru_model():
    model = Sequential([
        GRU(256, return_sequences=True, input_shape=(n_timesteps, n_features)),
        Dropout(0.3),
        GRU(128),
        Dropout(0.3),
        Dense(128, activation='relu'),
        Dropout(0.4),
        Dense(n_outputs, activation='softmax')
    ])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

fold_no = 1
cv_acc_list = []

for tr_idx, vl_idx in kfold.split(X_all, y_all_int):
    print(f"\n▶ Fold {fold_no}")
    X_tr, X_vl = X_all[tr_idx], X_all[vl_idx]
    y_tr, y_vl = y_all_one_hot[tr_idx], y_all_one_hot[vl_idx]

    model_cv = create_gru_model()
    model_cv.fit(X_tr, y_tr, epochs=30, batch_size=64, validation_data=(X_vl, y_vl), verbose=0)

    loss_cv, acc_cv = model_cv.evaluate(X_vl, y_vl, verbose=0)
    print(f"Fold {fold_no} - val_loss: {loss_cv:.4f}, val_acc: {acc_cv:.4f}")

    cv_acc_list.append(acc_cv)
    fold_no += 1

print("\n===== Cross Validation Result (GRU) =====")
print("Fold Accuracies:", [f"{a:.4f}" for a in cv_acc_list])
print(f"Mean Accuracy: {np.mean(cv_acc_list):.4f} ± {np.std(cv_acc_list):.4f}")
# Out:
# ===== 5-Fold Cross Validation (GRU) =====
#
# ▶ Fold 1
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Fold 1 - val_loss: 0.1000, val_acc: 0.9572
#
# ▶ Fold 2
# Fold 2 - val_loss: 0.1066, val_acc: 0.9436
#
# ▶ Fold 3
# Fold 3 - val_loss: 0.1108, val_acc: 0.9592
#
# ▶ Fold 4
# Fold 4 - val_loss: 0.1132, val_acc: 0.9483
#
# ▶ Fold 5
# Fold 5 - val_loss: 0.1165, val_acc: 0.9578
#
# ===== Cross Validation Result (GRU) =====
# Fold Accuracies: ['0.9572', '0.9436', '0.9592', '0.9483', '0.9578']
# Mean Accuracy: 0.9532 ± 0.0062
