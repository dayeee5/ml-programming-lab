# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense, Flatten,
    Conv1D, MaxPooling1D,
    LSTM, GRU
)

# %%
# -----------------------------
# 1) 파일 로드 함수 정의
# -----------------------------

def load_file(filepath):
    """공백(whitespace)으로 구분된 txt 파일을 읽어서 numpy 배열로 변환"""
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

def load_group(filenames, prefix=''):
    """여러 센서 파일을 불러와서 (샘플, 타임스텝, 특성) 형태의 3D 배열로 결합"""
    loaded = []
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    loaded = np.dstack(loaded)
    return loaded

def load_dataset_group(group, prefix=''):
    """train/test 그룹별로 9개 센서 신호 + 라벨 로드"""
    filepath = prefix + '/' + group + '/Inertial Signals/'

    filenames = []
    # 총가속도
    filenames += ['total_acc_x_' + group + '.txt',
                  'total_acc_y_' + group + '.txt',
                  'total_acc_z_' + group + '.txt']
    # 신체가속도
    filenames += ['body_acc_x_' + group + '.txt',
                  'body_acc_y_' + group + '.txt',
                  'body_acc_z_' + group + '.txt']
    # 자이로스코프
    filenames += ['body_gyro_x_' + group + '.txt',
                  'body_gyro_y_' + group + '.txt',
                  'body_gyro_z_' + group + '.txt']

    X = load_group(filenames, filepath)
    y = load_file(prefix + '/' + group + '/y_' + group + '.txt')
    return X, y

# %%
def load_dataset(prefix=''):
    """전체 train / test 데이터셋 로드 + 원-핫 인코딩"""
    base_path = prefix + '/content/drive/MyDrive/ml-programming-lab/week10/UCI HAR Dataset'

    trainX, trainy = load_dataset_group('train', base_path)
    testX, testy = load_dataset_group('test', base_path)

    # 라벨을 0 ~ 5로 맞추기 (원래 1~6)
    trainy = trainy - 1
    testy = testy - 1

    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)

    print("trainX:", trainX.shape,
          "trainy:", trainy.shape,
          "trainy_one_hot:", trainy_one_hot.shape)
    print("testX:", testX.shape,
          "testy:", testy.shape,
          "testy_one_hot:", testy_one_hot.shape)

    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %%
# -----------------------------
# 2) 데이터 로드 + 스케일링
# -----------------------------

trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset(prefix='')

print(f"원본 trainX shape: {trainX.shape}, testX shape: {testX.shape}")

# --- 스케일링 ---
scaler = StandardScaler()
trainX_reshaped = trainX.reshape((trainX.shape[0], -1))
testX_reshaped  = testX.reshape((testX.shape[0], -1))
trainX_scaled = scaler.fit_transform(trainX_reshaped).reshape(trainX.shape)
testX_scaled  = scaler.transform(testX_reshaped).reshape(testX.shape)

# --- Train / Validation Split ---
X_train, X_val, y_train_one_hot, y_val_one_hot, y_train, y_val = train_test_split(
    trainX_scaled, trainy_one_hot, trainy, test_size=0.2, random_state=100
)
# Out:
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# trainX: (7352, 128, 9) trainy: (7352, 1) trainy_one_hot: (7352, 6)
# testX: (2947, 128, 9) testy: (2947, 1) testy_one_hot: (2947, 6)
# 원본 trainX shape: (7352, 128, 9), testX shape: (2947, 128, 9)

# %%
# -----------------------------
# 3) 입력 차원 및 클래스 개수 설정
# -----------------------------

n_timesteps = X_train.shape[1]
n_features  = X_train.shape[2]
n_outputs   = y_train_one_hot.shape[1]

print("n_timesteps:", n_timesteps)
print("n_features :", n_features)
print("n_outputs  :", n_outputs)
# Out:
# n_timesteps: 128
# n_features : 9
# n_outputs  : 6

# %%
# -----------------------------
# 4) GRU 모델 정의 및 학습
# -----------------------------

# 모델 정의
gru_model = Sequential([
    GRU(128, input_shape=(n_timesteps, n_features)),
    Dense(64, activation='relu'),
    Dense(n_outputs, activation='softmax')
])

# 모델 컴파일
gru_model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

# 모델 구조 요약
gru_model.summary()

# 모델 학습
history_gru = gru_model.fit(
    X_train, y_train_one_hot,
    epochs=30,
    batch_size=32,
    validation_data=(X_val, y_val_one_hot),
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 128)            │        53,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 62,022 (242.27 KB)
#  Trainable params: 62,022 (242.27 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5929 - loss: 1.1118 - val_accuracy: 0.9014 - val_loss: 0.2806
# Epoch 2/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9109 - loss: 0.2631 - val_accuracy: 0.9273 - val_loss: 0.1573
# Epoch 3/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9460 - loss: 0.1394 - val_accuracy: 0.9449 - val_loss: 0.1520
# Epoch 4/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9452 - loss: 0.1448 - val_accuracy: 0.9517 - val_loss: 0.1355
# Epoch 5/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9532 - loss: 0.1183 - val_accuracy: 0.9415 - val_loss: 0.1236
# Epoch 6/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9439 - loss: 0.1212 - val_accuracy: 0.9443 - val_loss: 0.1379
# Epoch 7/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9454 - loss: 0.1197 - val_accuracy: 0.9415 - val_loss: 0.1254
# Epoch 8/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9506 - loss: 0.1131 - val_accuracy: 0.9422 - val_loss: 0.1192
# Epoch 9/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9518 - loss: 0.1096 - val_accuracy: 0.9415 - val_loss: 0.1188
# Epoch 10/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9571 - loss: 0.1069 - val_accuracy: 0.9436 - val_loss: 0.1165
# Epoch 11/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9523 - loss: 0.0992 - val_accuracy: 0.9511 - val_loss: 0.1204
# Epoch 12/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9519 - loss: 0.1111 - val_accuracy: 0.9490 - val_loss: 0.1105
# Epoch 13/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9520 - loss: 0.1072 - val_accuracy: 0.9477 - val_loss: 0.1157
# Epoch 14/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9542 - loss: 0.1045 - val_accuracy: 0.9504 - val_loss: 0.1113
# Epoch 15/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9533 - loss: 0.1038 - val_accuracy: 0.9524 - val_loss: 0.1079
# Epoch 16/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9529 - loss: 0.1085 - val_accuracy: 0.9273 - val_loss: 0.1826
# Epoch 17/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9418 - loss: 0.1502 - val_accuracy: 0.9483 - val_loss: 0.1167
# Epoch 18/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9567 - loss: 0.1073 - val_accuracy: 0.9504 - val_loss: 0.1131
# Epoch 19/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9616 - loss: 0.0970 - val_accuracy: 0.9449 - val_loss: 0.1246
# Epoch 20/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9574 - loss: 0.0958 - val_accuracy: 0.9511 - val_loss: 0.1038
# Epoch 21/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9617 - loss: 0.0904 - val_accuracy: 0.9388 - val_loss: 0.1409
# Epoch 22/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9553 - loss: 0.0992 - val_accuracy: 0.9511 - val_loss: 0.1117
# Epoch 23/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9639 - loss: 0.0873 - val_accuracy: 0.9538 - val_loss: 0.1032
# Epoch 24/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9583 - loss: 0.0929 - val_accuracy: 0.9524 - val_loss: 0.1040
# Epoch 25/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9603 - loss: 0.0964 - val_accuracy: 0.9497 - val_loss: 0.1079
# Epoch 26/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9597 - loss: 0.0882 - val_accuracy: 0.9531 - val_loss: 0.0977
# Epoch 27/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9640 - loss: 0.0841 - val_accuracy: 0.9524 - val_loss: 0.1121
# Epoch 28/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9596 - loss: 0.0884 - val_accuracy: 0.9524 - val_loss: 0.1091
# Epoch 29/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9649 - loss: 0.0865 - val_accuracy: 0.9415 - val_loss: 0.1408
# Epoch 30/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9616 - loss: 0.0902 - val_accuracy: 0.9517 - val_loss: 0.0855

# %%
# -----------------------------
# 5) 학습 곡선 시각화
# -----------------------------

# 학습 손실 곡선
loss = history_gru.history['loss']
val_loss = history_gru.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation Loss - GRU')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 학습 정확도 곡선
acc = history_gru.history['accuracy']
val_acc = history_gru.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and Validation Accuracy - GRU')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# -----------------------------
# 6) 모델 평가
# -----------------------------

# 테스트 데이터 예측
pred = gru_model.predict(testX_scaled)
pred = np.argmax(pred, axis=-1)

# 혼동 행렬 및 정확도 출력
cm = confusion_matrix(testy, pred)
print("Confusion Matrix:\n", cm)
print("\nAccuracy:", accuracy_score(testy, pred))
print("\nClassification Report:\n", classification_report(testy, pred))

# 혼동 행렬 시각화
sns.heatmap(cm, annot=True, fmt='.2f', cmap='magma')
plt.title('Confusion Matrix - GRU')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Confusion Matrix:
#  [[495   0   1   0   0   0]
#  [ 10 454   7   0   0   0]
#  [ 12   7 400   0   1   0]
#  [  0   4   0 410  72   5]
#  [  0   0   0  93 439   0]
#  [  0   0   0   0   0 537]]
#
# Accuracy: 0.9280624363759755
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       496
#            1       0.98      0.96      0.97       471
#            2       0.98      0.95      0.97       420
#            3       0.82      0.84      0.82       491
#            4       0.86      0.83      0.84       532
#            5       0.99      1.00      1.00       537
#
#     accuracy                           0.93      2947
#    macro avg       0.93      0.93      0.93      2947
# weighted avg       0.93      0.93      0.93      2947
