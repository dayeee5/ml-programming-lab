# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense, Flatten,
    Conv1D, MaxPooling1D,
    LSTM, GRU,
    Dropout, BatchNormalization
)

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# -----------------------------
# 1) 파일 로드 함수 정의
# -----------------------------

def load_file(filepath):
    """공백(whitespace)으로 구분된 txt 파일을 읽어서 numpy 배열로 변환"""
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

def load_group(filenames, prefix=''):
    """여러 센서 파일을 불러와서 (샘플, 타임스텝, 특성) 형태의 3D 배열로 결합"""
    loaded = []
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    loaded = np.dstack(loaded)
    return loaded

def load_dataset_group(group, prefix=''):
    """train/test 그룹별로 9개 센서 신호 + 라벨 로드"""
    filepath = prefix + '/' + group + '/Inertial Signals/'

    filenames = []
    # 총가속도
    filenames += ['total_acc_x_' + group + '.txt',
                  'total_acc_y_' + group + '.txt',
                  'total_acc_z_' + group + '.txt']
    # 신체가속도
    filenames += ['body_acc_x_' + group + '.txt',
                  'body_acc_y_' + group + '.txt',
                  'body_acc_z_' + group + '.txt']
    # 자이로스코프
    filenames += ['body_gyro_x_' + group + '.txt',
                  'body_gyro_y_' + group + '.txt',
                  'body_gyro_z_' + group + '.txt']

    X = load_group(filenames, filepath)
    y = load_file(prefix + '/' + group + '/y_' + group + '.txt')
    return X, y

# %%
def load_dataset(prefix=''):
    """전체 train / test 데이터셋 로드 + 원-핫 인코딩"""
    base_path = prefix + '/content/drive/MyDrive/ml-programming-lab/week10/UCI HAR Dataset'

    trainX, trainy = load_dataset_group('train', base_path)
    testX, testy = load_dataset_group('test', base_path)

    # 라벨을 0 ~ 5로 맞추기 (원래 1~6)
    trainy = trainy - 1
    testy = testy - 1

    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)

    print("trainX:", trainX.shape,
          "trainy:", trainy.shape,
          "trainy_one_hot:", trainy_one_hot.shape)
    print("testX:", testX.shape,
          "testy:", testy.shape,
          "testy_one_hot:", testy_one_hot.shape)

    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %%
# -----------------------------
# 2) 데이터 로드 + 스케일링
# -----------------------------

trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset(prefix='')

print(f"원본 trainX shape: {trainX.shape}, testX shape: {testX.shape}")

# --- 스케일링 ---
scaler = StandardScaler()
trainX_reshaped = trainX.reshape((trainX.shape[0], -1))
testX_reshaped  = testX.reshape((testX.shape[0], -1))
trainX_scaled = scaler.fit_transform(trainX_reshaped).reshape(trainX.shape)
testX_scaled  = scaler.transform(testX_reshaped).reshape(testX.shape)

# --- Train / Validation Split ---
X_train, X_val, y_train_one_hot, y_val_one_hot, y_train, y_val = train_test_split(
    trainX_scaled, trainy_one_hot, trainy, test_size=0.2, random_state=100
)
# Out:
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# trainX: (7352, 128, 9) trainy: (7352, 1) trainy_one_hot: (7352, 6)
# testX: (2947, 128, 9) testy: (2947, 1) testy_one_hot: (2947, 6)
# 원본 trainX shape: (7352, 128, 9), testX shape: (2947, 128, 9)

# %%
# -----------------------------
# 3) 입력 차원 및 클래스 개수 설정
# -----------------------------

n_timesteps = X_train.shape[1]
n_features  = X_train.shape[2]
n_outputs   = y_train_one_hot.shape[1]

print("n_timesteps:", n_timesteps)
print("n_features :", n_features)
print("n_outputs  :", n_outputs)
# Out:
# n_timesteps: 128
# n_features : 9
# n_outputs  : 6

# %%
# -----------------------------
# 4) CNN + LSTM 모델 정의 및 학습
# -----------------------------

# 모델 정의
cnn_lstm_model = Sequential([
    # Conv 블록 1
    Conv1D(128, kernel_size=5, activation='relu', padding='same',
           input_shape=(n_timesteps, n_features)),
    BatchNormalization(),
    Conv1D(128, kernel_size=5, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),

    # Conv 블록 2
    Conv1D(256, kernel_size=3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),

    # LSTM
    LSTM(128, return_sequences=False),
    Dropout(0.5),

    # Dense
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(n_outputs, activation='softmax')
])

# 모델 컴파일
cnn_lstm_model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# 모델 구조 요약
cnn_lstm_model.summary()

# 콜백 설정 (조기 종료 + 학습률 감소)
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-5
    )
]

# 모델 학습
history_cnn_lstm = cnn_lstm_model.fit(
    X_train, y_train_one_hot,
    epochs=100,          # 30 → 100 (EarlyStopping이 알아서 멈춤)
    batch_size=64,       # 32 → 64
    validation_data=(X_val, y_val_one_hot),
    callbacks=callbacks,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_26 (Conv1D)              │ (None, 128, 128)       │         5,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 128, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_27 (Conv1D)              │ (None, 128, 128)       │        82,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 128, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_14 (MaxPooling1D) │ (None, 64, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_28 (Conv1D)              │ (None, 64, 256)        │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 64, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_15 (MaxPooling1D) │ (None, 32, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 32, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_12 (LSTM)                  │ (None, 128)            │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 402,950 (1.54 MB)
#  Trainable params: 401,926 (1.53 MB)
#  Non-trainable params: 1,024 (4.00 KB)
# Epoch 1/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.6510 - loss: 0.8819 - val_accuracy: 0.8273 - val_loss: 0.4858 - learning_rate: 0.0010
# Epoch 2/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9231 - loss: 0.2162 - val_accuracy: 0.9307 - val_loss: 0.1982 - learning_rate: 0.0010
# Epoch 3/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9393 - loss: 0.1653 - val_accuracy: 0.9402 - val_loss: 0.1782 - learning_rate: 0.0010
# Epoch 4/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9454 - loss: 0.1370 - val_accuracy: 0.9470 - val_loss: 0.1245 - learning_rate: 0.0010
# Epoch 5/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9511 - loss: 0.1283 - val_accuracy: 0.9497 - val_loss: 0.1247 - learning_rate: 0.0010
# Epoch 6/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9502 - loss: 0.1307 - val_accuracy: 0.9307 - val_loss: 0.1468 - learning_rate: 0.0010
# Epoch 7/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9467 - loss: 0.1389 - val_accuracy: 0.9381 - val_loss: 0.1355 - learning_rate: 0.0010
# Epoch 8/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9468 - loss: 0.1243 - val_accuracy: 0.9483 - val_loss: 0.1168 - learning_rate: 0.0010
# Epoch 9/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9503 - loss: 0.1264 - val_accuracy: 0.9504 - val_loss: 0.1082 - learning_rate: 0.0010
# Epoch 10/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9493 - loss: 0.1217 - val_accuracy: 0.9531 - val_loss: 0.1121 - learning_rate: 0.0010
# Epoch 11/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9520 - loss: 0.1208 - val_accuracy: 0.9490 - val_loss: 0.1198 - learning_rate: 0.0010
# Epoch 12/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9511 - loss: 0.1188 - val_accuracy: 0.9497 - val_loss: 0.1116 - learning_rate: 0.0010
# Epoch 13/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9587 - loss: 0.1067 - val_accuracy: 0.9470 - val_loss: 0.1046 - learning_rate: 0.0010
# Epoch 14/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9446 - loss: 0.1239 - val_accuracy: 0.9545 - val_loss: 0.1090 - learning_rate: 0.0010
# Epoch 15/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9534 - loss: 0.1141 - val_accuracy: 0.9504 - val_loss: 0.1180 - learning_rate: 0.0010
# Epoch 16/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9599 - loss: 0.1004 - val_accuracy: 0.9531 - val_loss: 0.1057 - learning_rate: 0.0010
# Epoch 17/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9583 - loss: 0.1040 - val_accuracy: 0.9490 - val_loss: 0.1108 - learning_rate: 0.0010
# Epoch 18/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9590 - loss: 0.1072 - val_accuracy: 0.9551 - val_loss: 0.1091 - learning_rate: 0.0010
# Epoch 19/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9557 - loss: 0.1091 - val_accuracy: 0.9531 - val_loss: 0.1015 - learning_rate: 5.0000e-04
# Epoch 20/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9584 - loss: 0.0954 - val_accuracy: 0.9551 - val_loss: 0.1035 - learning_rate: 5.0000e-04
# Epoch 21/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9578 - loss: 0.1009 - val_accuracy: 0.9504 - val_loss: 0.0984 - learning_rate: 5.0000e-04
# Epoch 22/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9534 - loss: 0.1045 - val_accuracy: 0.9551 - val_loss: 0.0939 - learning_rate: 5.0000e-04
# Epoch 23/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9583 - loss: 0.1116 - val_accuracy: 0.9538 - val_loss: 0.0929 - learning_rate: 5.0000e-04
# Epoch 24/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9607 - loss: 0.0936 - val_accuracy: 0.9545 - val_loss: 0.0944 - learning_rate: 5.0000e-04
# Epoch 25/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9498 - loss: 0.1117 - val_accuracy: 0.9524 - val_loss: 0.0996 - learning_rate: 5.0000e-04
# Epoch 26/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9605 - loss: 0.0918 - val_accuracy: 0.9531 - val_loss: 0.0949 - learning_rate: 5.0000e-04
# Epoch 27/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9618 - loss: 0.0856 - val_accuracy: 0.9531 - val_loss: 0.0990 - learning_rate: 5.0000e-04
# Epoch 28/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9621 - loss: 0.0973 - val_accuracy: 0.9565 - val_loss: 0.1047 - learning_rate: 5.0000e-04
# Epoch 29/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9547 - loss: 0.1019 - val_accuracy: 0.9538 - val_loss: 0.0928 - learning_rate: 2.5000e-04
# Epoch 30/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9612 - loss: 0.0903 - val_accuracy: 0.9538 - val_loss: 0.0882 - learning_rate: 2.5000e-04
# Epoch 31/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9617 - loss: 0.0957 - val_accuracy: 0.9558 - val_loss: 0.0901 - learning_rate: 2.5000e-04
# Epoch 32/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9627 - loss: 0.0817 - val_accuracy: 0.9558 - val_loss: 0.0890 - learning_rate: 2.5000e-04
# Epoch 33/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9612 - loss: 0.0882 - val_accuracy: 0.9531 - val_loss: 0.1002 - learning_rate: 2.5000e-04
# Epoch 34/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9665 - loss: 0.0846 - val_accuracy: 0.9565 - val_loss: 0.0870 - learning_rate: 2.5000e-04
# Epoch 35/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9651 - loss: 0.0771 - val_accuracy: 0.9572 - val_loss: 0.0861 - learning_rate: 2.5000e-04
# Epoch 36/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9638 - loss: 0.0816 - val_accuracy: 0.9565 - val_loss: 0.0813 - learning_rate: 2.5000e-04
# Epoch 37/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9669 - loss: 0.0803 - val_accuracy: 0.9565 - val_loss: 0.0822 - learning_rate: 2.5000e-04
# Epoch 38/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9679 - loss: 0.0756 - val_accuracy: 0.9592 - val_loss: 0.0819 - learning_rate: 2.5000e-04
# Epoch 39/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9679 - loss: 0.0749 - val_accuracy: 0.9579 - val_loss: 0.0821 - learning_rate: 2.5000e-04
# Epoch 40/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9625 - loss: 0.0797 - val_accuracy: 0.9585 - val_loss: 0.0780 - learning_rate: 2.5000e-04
# Epoch 41/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9641 - loss: 0.0825 - val_accuracy: 0.9572 - val_loss: 0.0860 - learning_rate: 2.5000e-04
# Epoch 42/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9688 - loss: 0.0755 - val_accuracy: 0.9585 - val_loss: 0.0724 - learning_rate: 2.5000e-04
# Epoch 43/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9664 - loss: 0.0764 - val_accuracy: 0.9606 - val_loss: 0.0852 - learning_rate: 2.5000e-04
# Epoch 44/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9661 - loss: 0.0780 - val_accuracy: 0.9463 - val_loss: 0.0936 - learning_rate: 2.5000e-04
# Epoch 45/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9610 - loss: 0.0773 - val_accuracy: 0.9572 - val_loss: 0.0792 - learning_rate: 2.5000e-04
# Epoch 46/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9605 - loss: 0.0923 - val_accuracy: 0.9619 - val_loss: 0.0684 - learning_rate: 2.5000e-04
# Epoch 47/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9631 - loss: 0.0787 - val_accuracy: 0.9619 - val_loss: 0.0663 - learning_rate: 2.5000e-04
# Epoch 48/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9698 - loss: 0.0667 - val_accuracy: 0.9633 - val_loss: 0.0650 - learning_rate: 2.5000e-04
# Epoch 49/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9722 - loss: 0.0600 - val_accuracy: 0.9714 - val_loss: 0.0802 - learning_rate: 2.5000e-04
# Epoch 50/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9699 - loss: 0.0667 - val_accuracy: 0.9606 - val_loss: 0.0635 - learning_rate: 2.5000e-04
# Epoch 51/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9708 - loss: 0.0644 - val_accuracy: 0.9680 - val_loss: 0.0576 - learning_rate: 2.5000e-04
# Epoch 52/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9709 - loss: 0.0677 - val_accuracy: 0.9687 - val_loss: 0.0664 - learning_rate: 2.5000e-04
# Epoch 53/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9680 - loss: 0.0671 - val_accuracy: 0.9694 - val_loss: 0.0730 - learning_rate: 2.5000e-04
# Epoch 54/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9710 - loss: 0.0645 - val_accuracy: 0.9674 - val_loss: 0.0685 - learning_rate: 2.5000e-04
# Epoch 55/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9716 - loss: 0.0622 - val_accuracy: 0.9626 - val_loss: 0.0656 - learning_rate: 2.5000e-04
# Epoch 56/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9648 - loss: 0.0766 - val_accuracy: 0.9674 - val_loss: 0.0752 - learning_rate: 2.5000e-04
# Epoch 57/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9715 - loss: 0.0611 - val_accuracy: 0.9680 - val_loss: 0.0616 - learning_rate: 1.2500e-04
# Epoch 58/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9707 - loss: 0.0630 - val_accuracy: 0.9708 - val_loss: 0.0661 - learning_rate: 1.2500e-04
# Epoch 59/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9732 - loss: 0.0558 - val_accuracy: 0.9708 - val_loss: 0.0572 - learning_rate: 1.2500e-04
# Epoch 60/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9735 - loss: 0.0519 - val_accuracy: 0.9708 - val_loss: 0.0601 - learning_rate: 1.2500e-04
# Epoch 61/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9764 - loss: 0.0458 - val_accuracy: 0.9680 - val_loss: 0.0582 - learning_rate: 1.2500e-04
# Epoch 62/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9763 - loss: 0.0507 - val_accuracy: 0.9680 - val_loss: 0.0725 - learning_rate: 1.2500e-04
# Epoch 63/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9707 - loss: 0.0598 - val_accuracy: 0.9714 - val_loss: 0.0573 - learning_rate: 1.2500e-04
# Epoch 64/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9751 - loss: 0.0505 - val_accuracy: 0.9701 - val_loss: 0.0593 - learning_rate: 1.2500e-04
# Epoch 65/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9752 - loss: 0.0492 - val_accuracy: 0.9728 - val_loss: 0.0531 - learning_rate: 6.2500e-05
# Epoch 66/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9732 - loss: 0.0518 - val_accuracy: 0.9735 - val_loss: 0.0518 - learning_rate: 6.2500e-05
# Epoch 67/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9741 - loss: 0.0502 - val_accuracy: 0.9701 - val_loss: 0.0533 - learning_rate: 6.2500e-05
# Epoch 68/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9726 - loss: 0.0491 - val_accuracy: 0.9728 - val_loss: 0.0549 - learning_rate: 6.2500e-05
# Epoch 69/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9781 - loss: 0.0456 - val_accuracy: 0.9708 - val_loss: 0.0536 - learning_rate: 6.2500e-05
# Epoch 70/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9754 - loss: 0.0461 - val_accuracy: 0.9728 - val_loss: 0.0529 - learning_rate: 6.2500e-05
# Epoch 71/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9758 - loss: 0.0473 - val_accuracy: 0.9714 - val_loss: 0.0535 - learning_rate: 6.2500e-05
# Epoch 72/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9788 - loss: 0.0435 - val_accuracy: 0.9701 - val_loss: 0.0524 - learning_rate: 3.1250e-05
# Epoch 73/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9805 - loss: 0.0399 - val_accuracy: 0.9708 - val_loss: 0.0529 - learning_rate: 3.1250e-05
# Epoch 74/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9747 - loss: 0.0443 - val_accuracy: 0.9714 - val_loss: 0.0516 - learning_rate: 3.1250e-05
# Epoch 75/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9769 - loss: 0.0433 - val_accuracy: 0.9728 - val_loss: 0.0517 - learning_rate: 3.1250e-05
# Epoch 76/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9783 - loss: 0.0428 - val_accuracy: 0.9701 - val_loss: 0.0471 - learning_rate: 3.1250e-05
# Epoch 77/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9779 - loss: 0.0474 - val_accuracy: 0.9728 - val_loss: 0.0513 - learning_rate: 3.1250e-05
# Epoch 78/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9779 - loss: 0.0387 - val_accuracy: 0.9701 - val_loss: 0.0548 - learning_rate: 3.1250e-05
# Epoch 79/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9754 - loss: 0.0437 - val_accuracy: 0.9721 - val_loss: 0.0522 - learning_rate: 3.1250e-05
# Epoch 80/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9758 - loss: 0.0429 - val_accuracy: 0.9708 - val_loss: 0.0566 - learning_rate: 3.1250e-05
# Epoch 81/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9807 - loss: 0.0379 - val_accuracy: 0.9714 - val_loss: 0.0556 - learning_rate: 3.1250e-05
# Epoch 82/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9770 - loss: 0.0417 - val_accuracy: 0.9714 - val_loss: 0.0514 - learning_rate: 1.5625e-05
# Epoch 83/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9796 - loss: 0.0422 - val_accuracy: 0.9721 - val_loss: 0.0539 - learning_rate: 1.5625e-05
# Epoch 84/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9769 - loss: 0.0420 - val_accuracy: 0.9708 - val_loss: 0.0499 - learning_rate: 1.5625e-05
# Epoch 85/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9830 - loss: 0.0371 - val_accuracy: 0.9708 - val_loss: 0.0502 - learning_rate: 1.5625e-05
# Epoch 86/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9826 - loss: 0.0391 - val_accuracy: 0.9694 - val_loss: 0.0503 - learning_rate: 1.5625e-05

# %%
# -----------------------------
# 5) 학습 곡선 시각화
# -----------------------------

# 학습 손실 곡선
loss = history_cnn_lstm.history['loss']
val_loss = history_cnn_lstm.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation Loss - CNN + LSTM')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 학습 정확도 곡선
acc = history_cnn_lstm.history['accuracy']
val_acc = history_cnn_lstm.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and Validation Accuracy - CNN + LSTM')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# -----------------------------
# 6) 모델 평가
# -----------------------------

# 테스트 데이터 예측
pred = cnn_lstm_model.predict(testX_scaled)
pred = np.argmax(pred, axis=-1)

# 혼동 행렬 및 정확도 출력
cm = confusion_matrix(testy, pred)
print("Confusion Matrix:\n", cm)
print("\nAccuracy:", accuracy_score(testy, pred))
print("\nClassification Report:\n", classification_report(testy, pred))

 # 혼동 행렬 시각화
sns.heatmap(cm, annot=True, fmt='.2f', cmap='magma')
plt.title('Confusion Matrix - CNN + LSTM')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Confusion Matrix:
#  [[496   0   0   0   0   0]
#  [  4 455   9   3   0   0]
#  [  1   1 418   0   0   0]
#  [  0   3   0 399  84   5]
#  [  0   1   0  95 436   0]
#  [  0   0   0   0   0 537]]
#
# Accuracy: 0.9300984051577876
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       496
#            1       0.99      0.97      0.98       471
#            2       0.98      1.00      0.99       420
#            3       0.80      0.81      0.81       491
#            4       0.84      0.82      0.83       532
#            5       0.99      1.00      1.00       537
#
#     accuracy                           0.93      2947
#    macro avg       0.93      0.93      0.93      2947
# weighted avg       0.93      0.93      0.93      2947

# %%
# -----------------------------
# 7) 5-Fold 교차 검증
# -----------------------------

print("\n===== 5-Fold Cross Validation (CNN + LSTM) =====")

# 전체 train 세트 사용
X_all = trainX_scaled              # (전체 학습 입력)
y_all_int = trainy.flatten()       # 정수 라벨 (0~5)
y_all_one_hot = trainy_one_hot     # 원-핫 라벨

# 폴드 분할 설정 (라벨 비율 유지)
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# 교차 검증용 모델 생성 함수
def create_cnn_lstm_model():
    model = Sequential([
        Conv1D(64, kernel_size=3, activation='relu', input_shape=(n_timesteps, n_features)),
        Conv1D(64, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        LSTM(128),
        Dense(64, activation='relu'),
        Dense(n_outputs, activation='softmax')
    ])
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    return model

fold_no = 1
cv_acc_list = []

for train_idx, val_idx in kfold.split(X_all, y_all_int):
    print(f"\n▶ Fold {fold_no}")

    # 폴드별 train / val 나누기
    X_tr, X_vl = X_all[train_idx], X_all[val_idx]
    y_tr, y_vl = y_all_one_hot[train_idx], y_all_one_hot[val_idx]

    # 폴드마다 새로운 모델 생성
    model_cv = create_cnn_lstm_model()

    # 학습 (조금 줄여서 20 epoch 정도)
    history_cv = model_cv.fit(
        X_tr, y_tr,
        epochs=20,
        batch_size=32,
        validation_data=(X_vl, y_vl),
        verbose=0
    )

    # 검증 성능 평가
    loss_cv, acc_cv = model_cv.evaluate(X_vl, y_vl, verbose=0)
    print(f"Fold {fold_no} - val_loss: {loss_cv:.4f}, val_acc: {acc_cv:.4f}")

    cv_acc_list.append(acc_cv)
    fold_no += 1

print("\n===== Cross Validation Result (CNN + LSTM) =====")
print("Fold Accuracies:", [f"{a:.4f}" for a in cv_acc_list])
print(f"Mean Accuracy: {np.mean(cv_acc_list):.4f} ± {np.std(cv_acc_list):.4f}")
# Out:
# ===== 5-Fold Cross Validation (CNN + LSTM) =====
#
# ▶ Fold 1
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Fold 1 - val_loss: 0.1008, val_acc: 0.9511
#
# ▶ Fold 2
# Fold 2 - val_loss: 0.0983, val_acc: 0.9551
#
# ▶ Fold 3
# Fold 3 - val_loss: 0.1165, val_acc: 0.9524
#
# ▶ Fold 4
# Fold 4 - val_loss: 0.0928, val_acc: 0.9592
#
# ▶ Fold 5
# Fold 5 - val_loss: 0.0934, val_acc: 0.9571
#
# ===== Cross Validation Result (CNN + LSTM) =====
# Fold Accuracies: ['0.9511', '0.9551', '0.9524', '0.9592', '0.9571']
# Mean Accuracy: 0.9550 ± 0.0030
