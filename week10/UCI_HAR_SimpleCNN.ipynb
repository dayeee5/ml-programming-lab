# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense, Flatten,
    Conv1D, MaxPooling1D,
    LSTM, GRU,
    Dropout, BatchNormalization
)

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# -----------------------------
# 1) 파일 로드 함수 정의
# -----------------------------

def load_file(filepath):
    """공백(whitespace)으로 구분된 txt 파일을 읽어서 numpy 배열로 변환"""
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

def load_group(filenames, prefix=''):
    """여러 센서 파일을 불러와서 (샘플, 타임스텝, 특성) 형태의 3D 배열로 결합"""
    loaded = []
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    loaded = np.dstack(loaded)
    return loaded

def load_dataset_group(group, prefix=''):
    """train/test 그룹별로 9개 센서 신호 + 라벨 로드"""
    filepath = prefix + '/' + group + '/Inertial Signals/'

    filenames = []
    # 총가속도
    filenames += ['total_acc_x_' + group + '.txt',
                  'total_acc_y_' + group + '.txt',
                  'total_acc_z_' + group + '.txt']
    # 신체가속도
    filenames += ['body_acc_x_' + group + '.txt',
                  'body_acc_y_' + group + '.txt',
                  'body_acc_z_' + group + '.txt']
    # 자이로스코프
    filenames += ['body_gyro_x_' + group + '.txt',
                  'body_gyro_y_' + group + '.txt',
                  'body_gyro_z_' + group + '.txt']

    X = load_group(filenames, filepath)
    y = load_file(prefix + '/' + group + '/y_' + group + '.txt')
    return X, y

# %%
def load_dataset(prefix=''):
    """전체 train / test 데이터셋 로드 + 원-핫 인코딩"""
    base_path = prefix + '/content/drive/MyDrive/ml-programming-lab/week10/UCI HAR Dataset'

    trainX, trainy = load_dataset_group('train', base_path)
    testX, testy = load_dataset_group('test', base_path)

    # 라벨을 0 ~ 5로 맞추기 (원래 1~6)
    trainy = trainy - 1
    testy = testy - 1

    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)

    print("trainX:", trainX.shape,
          "trainy:", trainy.shape,
          "trainy_one_hot:", trainy_one_hot.shape)
    print("testX:", testX.shape,
          "testy:", testy.shape,
          "testy_one_hot:", testy_one_hot.shape)

    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %%
# -----------------------------
# 2) 데이터 로드 + 스케일링
# -----------------------------

trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset(prefix='')

print(f"원본 trainX shape: {trainX.shape}, testX shape: {testX.shape}")

# --- 스케일링 ---
scaler = StandardScaler()
trainX_reshaped = trainX.reshape((trainX.shape[0], -1))
testX_reshaped  = testX.reshape((testX.shape[0], -1))
trainX_scaled = scaler.fit_transform(trainX_reshaped).reshape(trainX.shape)
testX_scaled  = scaler.transform(testX_reshaped).reshape(testX.shape)

# --- Train / Validation Split ---
X_train, X_val, y_train_one_hot, y_val_one_hot, y_train, y_val = train_test_split(
    trainX_scaled, trainy_one_hot, trainy, test_size=0.2, random_state=100
)
# Out:
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1685226877.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# trainX: (7352, 128, 9) trainy: (7352, 1) trainy_one_hot: (7352, 6)
# testX: (2947, 128, 9) testy: (2947, 1) testy_one_hot: (2947, 6)
# 원본 trainX shape: (7352, 128, 9), testX shape: (2947, 128, 9)

# %%
# -----------------------------
# 3) 입력 차원 및 클래스 개수 설정
# -----------------------------

n_timesteps = X_train.shape[1]
n_features  = X_train.shape[2]
n_outputs   = y_train_one_hot.shape[1]

print("n_timesteps:", n_timesteps)
print("n_features :", n_features)
print("n_outputs  :", n_outputs)
# Out:
# n_timesteps: 128
# n_features : 9
# n_outputs  : 6

# %%
# -----------------------------
# 4) Simple CNN 모델 정의 및 학습
# -----------------------------

# 모델 정의
simpleCnn_model = Sequential([
    # Conv 블록 1
    Conv1D(128, kernel_size=5, activation='relu', padding='same',
           input_shape=(n_timesteps, n_features)),
    BatchNormalization(),
    Conv1D(128, kernel_size=5, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),

    # Conv 블록 2
    Conv1D(256, kernel_size=3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),

    # 완전연결
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(n_outputs, activation='softmax')
])

# 모델 컴파일
simpleCnn_model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# 모델 구조 요약
simpleCnn_model.summary()

# 콜백 설정 (조기 종료 + 학습률 감소)
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-5
    )
]

# 모델 학습
history_simpleCnn = simpleCnn_model.fit(
    X_train, y_train_one_hot,
    epochs=100,          # 30 → 100 (EarlyStopping이 알아서 멈춤)
    batch_size=64,       # 32 → 64
    validation_data=(X_val, y_val_one_hot),
    callbacks=callbacks,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_9 (Conv1D)               │ (None, 128, 128)       │         5,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 128, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 128, 128)       │        82,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 128, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 64, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 64, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 64, 256)        │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 64, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 32, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 32, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │     2,097,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 6)              │         1,542 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,287,494 (8.73 MB)
#  Trainable params: 2,286,470 (8.72 MB)
#  Non-trainable params: 1,024 (4.00 KB)
# Epoch 1/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 12s 59ms/step - accuracy: 0.7406 - loss: 1.3717 - val_accuracy: 0.5744 - val_loss: 1.6441 - learning_rate: 0.0010
# Epoch 2/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9415 - loss: 0.1595 - val_accuracy: 0.7757 - val_loss: 1.0717 - learning_rate: 0.0010
# Epoch 3/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9408 - loss: 0.1662 - val_accuracy: 0.9361 - val_loss: 0.2326 - learning_rate: 0.0010
# Epoch 4/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9328 - loss: 0.1734 - val_accuracy: 0.9483 - val_loss: 0.1554 - learning_rate: 0.0010
# Epoch 5/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9357 - loss: 0.1925 - val_accuracy: 0.9497 - val_loss: 0.1340 - learning_rate: 0.0010
# Epoch 6/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9425 - loss: 0.1423 - val_accuracy: 0.9334 - val_loss: 0.3766 - learning_rate: 0.0010
# Epoch 7/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9434 - loss: 0.1647 - val_accuracy: 0.9524 - val_loss: 0.1300 - learning_rate: 0.0010
# Epoch 8/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9468 - loss: 0.1284 - val_accuracy: 0.9443 - val_loss: 0.1201 - learning_rate: 0.0010
# Epoch 9/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9401 - loss: 0.1801 - val_accuracy: 0.9415 - val_loss: 0.1345 - learning_rate: 0.0010
# Epoch 10/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9536 - loss: 0.1299 - val_accuracy: 0.9545 - val_loss: 0.1095 - learning_rate: 0.0010
# Epoch 11/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9383 - loss: 0.1878 - val_accuracy: 0.9477 - val_loss: 0.1386 - learning_rate: 0.0010
# Epoch 12/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9491 - loss: 0.1330 - val_accuracy: 0.9456 - val_loss: 0.1482 - learning_rate: 0.0010
# Epoch 13/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9484 - loss: 0.1264 - val_accuracy: 0.9511 - val_loss: 0.1039 - learning_rate: 0.0010
# Epoch 14/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9462 - loss: 0.1519 - val_accuracy: 0.9504 - val_loss: 0.1193 - learning_rate: 0.0010
# Epoch 15/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9541 - loss: 0.1118 - val_accuracy: 0.9538 - val_loss: 0.1027 - learning_rate: 0.0010
# Epoch 16/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9505 - loss: 0.1188 - val_accuracy: 0.9511 - val_loss: 0.1100 - learning_rate: 0.0010
# Epoch 17/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9445 - loss: 0.1498 - val_accuracy: 0.9477 - val_loss: 0.1262 - learning_rate: 0.0010
# Epoch 18/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9477 - loss: 0.1569 - val_accuracy: 0.9504 - val_loss: 0.1213 - learning_rate: 0.0010
# Epoch 19/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9514 - loss: 0.1134 - val_accuracy: 0.9477 - val_loss: 0.1084 - learning_rate: 0.0010
# Epoch 20/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9509 - loss: 0.1121 - val_accuracy: 0.9517 - val_loss: 0.1064 - learning_rate: 0.0010
# Epoch 21/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9574 - loss: 0.0952 - val_accuracy: 0.9517 - val_loss: 0.1023 - learning_rate: 5.0000e-04
# Epoch 22/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9578 - loss: 0.0925 - val_accuracy: 0.9531 - val_loss: 0.1075 - learning_rate: 5.0000e-04
# Epoch 23/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9546 - loss: 0.0955 - val_accuracy: 0.9551 - val_loss: 0.1019 - learning_rate: 5.0000e-04
# Epoch 24/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9536 - loss: 0.1022 - val_accuracy: 0.9538 - val_loss: 0.0990 - learning_rate: 5.0000e-04
# Epoch 25/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9580 - loss: 0.0963 - val_accuracy: 0.9572 - val_loss: 0.0949 - learning_rate: 5.0000e-04
# Epoch 26/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9521 - loss: 0.0937 - val_accuracy: 0.9592 - val_loss: 0.1124 - learning_rate: 5.0000e-04
# Epoch 27/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9627 - loss: 0.0817 - val_accuracy: 0.9511 - val_loss: 0.1070 - learning_rate: 5.0000e-04
# Epoch 28/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9543 - loss: 0.0927 - val_accuracy: 0.9565 - val_loss: 0.0895 - learning_rate: 5.0000e-04
# Epoch 29/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9554 - loss: 0.0993 - val_accuracy: 0.9545 - val_loss: 0.0937 - learning_rate: 5.0000e-04
# Epoch 30/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9629 - loss: 0.0815 - val_accuracy: 0.9585 - val_loss: 0.1181 - learning_rate: 5.0000e-04
# Epoch 31/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9530 - loss: 0.1128 - val_accuracy: 0.9490 - val_loss: 0.1506 - learning_rate: 5.0000e-04
# Epoch 32/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9576 - loss: 0.1010 - val_accuracy: 0.9531 - val_loss: 0.1203 - learning_rate: 5.0000e-04
# Epoch 33/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9509 - loss: 0.0989 - val_accuracy: 0.9517 - val_loss: 0.1150 - learning_rate: 5.0000e-04
# Epoch 34/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9551 - loss: 0.0962 - val_accuracy: 0.9545 - val_loss: 0.0855 - learning_rate: 2.5000e-04
# Epoch 35/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9622 - loss: 0.0793 - val_accuracy: 0.9579 - val_loss: 0.0797 - learning_rate: 2.5000e-04
# Epoch 36/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9620 - loss: 0.0825 - val_accuracy: 0.9579 - val_loss: 0.0810 - learning_rate: 2.5000e-04
# Epoch 37/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9632 - loss: 0.0806 - val_accuracy: 0.9592 - val_loss: 0.0890 - learning_rate: 2.5000e-04
# Epoch 38/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9656 - loss: 0.0724 - val_accuracy: 0.9613 - val_loss: 0.0813 - learning_rate: 2.5000e-04
# Epoch 39/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9584 - loss: 0.0823 - val_accuracy: 0.9613 - val_loss: 0.0792 - learning_rate: 2.5000e-04
# Epoch 40/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9566 - loss: 0.0866 - val_accuracy: 0.9585 - val_loss: 0.0750 - learning_rate: 2.5000e-04
# Epoch 41/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9653 - loss: 0.0743 - val_accuracy: 0.9585 - val_loss: 0.0808 - learning_rate: 2.5000e-04
# Epoch 42/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9601 - loss: 0.0873 - val_accuracy: 0.9551 - val_loss: 0.1045 - learning_rate: 2.5000e-04
# Epoch 43/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9629 - loss: 0.0692 - val_accuracy: 0.9565 - val_loss: 0.0957 - learning_rate: 2.5000e-04
# Epoch 44/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9595 - loss: 0.0827 - val_accuracy: 0.9640 - val_loss: 0.0761 - learning_rate: 2.5000e-04
# Epoch 45/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9649 - loss: 0.0703 - val_accuracy: 0.9579 - val_loss: 0.0816 - learning_rate: 2.5000e-04
# Epoch 46/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9698 - loss: 0.0662 - val_accuracy: 0.9619 - val_loss: 0.0720 - learning_rate: 1.2500e-04
# Epoch 47/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9632 - loss: 0.0651 - val_accuracy: 0.9640 - val_loss: 0.0794 - learning_rate: 1.2500e-04
# Epoch 48/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9644 - loss: 0.0678 - val_accuracy: 0.9626 - val_loss: 0.0727 - learning_rate: 1.2500e-04
# Epoch 49/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9679 - loss: 0.0634 - val_accuracy: 0.9640 - val_loss: 0.0667 - learning_rate: 1.2500e-04
# Epoch 50/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9690 - loss: 0.0610 - val_accuracy: 0.9653 - val_loss: 0.0770 - learning_rate: 1.2500e-04
# Epoch 51/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9678 - loss: 0.0655 - val_accuracy: 0.9653 - val_loss: 0.0866 - learning_rate: 1.2500e-04
# Epoch 52/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9685 - loss: 0.0635 - val_accuracy: 0.9626 - val_loss: 0.0821 - learning_rate: 1.2500e-04
# Epoch 53/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9662 - loss: 0.0631 - val_accuracy: 0.9646 - val_loss: 0.0747 - learning_rate: 1.2500e-04
# Epoch 54/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9708 - loss: 0.0584 - val_accuracy: 0.9619 - val_loss: 0.0840 - learning_rate: 1.2500e-04
# Epoch 55/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9690 - loss: 0.0608 - val_accuracy: 0.9687 - val_loss: 0.0818 - learning_rate: 6.2500e-05
# Epoch 56/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9698 - loss: 0.0556 - val_accuracy: 0.9653 - val_loss: 0.0771 - learning_rate: 6.2500e-05
# Epoch 57/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9733 - loss: 0.0545 - val_accuracy: 0.9694 - val_loss: 0.0633 - learning_rate: 6.2500e-05
# Epoch 58/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9733 - loss: 0.0546 - val_accuracy: 0.9667 - val_loss: 0.0774 - learning_rate: 6.2500e-05
# Epoch 59/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9715 - loss: 0.0559 - val_accuracy: 0.9674 - val_loss: 0.0749 - learning_rate: 6.2500e-05
# Epoch 60/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9736 - loss: 0.0546 - val_accuracy: 0.9674 - val_loss: 0.0619 - learning_rate: 6.2500e-05
# Epoch 61/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9726 - loss: 0.0590 - val_accuracy: 0.9721 - val_loss: 0.0623 - learning_rate: 6.2500e-05
# Epoch 62/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9711 - loss: 0.0573 - val_accuracy: 0.9674 - val_loss: 0.0717 - learning_rate: 6.2500e-05
# Epoch 63/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9760 - loss: 0.0477 - val_accuracy: 0.9687 - val_loss: 0.0589 - learning_rate: 6.2500e-05
# Epoch 64/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9689 - loss: 0.0626 - val_accuracy: 0.9755 - val_loss: 0.0590 - learning_rate: 6.2500e-05
# Epoch 65/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9700 - loss: 0.0562 - val_accuracy: 0.9680 - val_loss: 0.0637 - learning_rate: 6.2500e-05
# Epoch 66/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9679 - loss: 0.0560 - val_accuracy: 0.9694 - val_loss: 0.0598 - learning_rate: 6.2500e-05
# Epoch 67/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9705 - loss: 0.0560 - val_accuracy: 0.9742 - val_loss: 0.0747 - learning_rate: 6.2500e-05
# Epoch 68/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9715 - loss: 0.0563 - val_accuracy: 0.9667 - val_loss: 0.0834 - learning_rate: 6.2500e-05
# Epoch 69/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9713 - loss: 0.0595 - val_accuracy: 0.9721 - val_loss: 0.0634 - learning_rate: 3.1250e-05
# Epoch 70/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9721 - loss: 0.0551 - val_accuracy: 0.9714 - val_loss: 0.0664 - learning_rate: 3.1250e-05
# Epoch 71/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9696 - loss: 0.0579 - val_accuracy: 0.9721 - val_loss: 0.0743 - learning_rate: 3.1250e-05
# Epoch 72/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9781 - loss: 0.0467 - val_accuracy: 0.9755 - val_loss: 0.0642 - learning_rate: 3.1250e-05
# Epoch 73/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9750 - loss: 0.0506 - val_accuracy: 0.9687 - val_loss: 0.0631 - learning_rate: 3.1250e-05

# %%
# -----------------------------
# 5) 학습 곡선 시각화
# -----------------------------

# 학습 손실 곡선
loss = history_simpleCnn.history['loss']
val_loss = history_simpleCnn.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation Loss - Simple CNN')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 학습 정확도 곡선
acc = history_simpleCnn.history['accuracy']
val_acc = history_simpleCnn.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and Validation Accuracy - Simple CNN')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# -----------------------------
# 6) 모델 평가
# -----------------------------

# 테스트 데이터 예측
pred = simpleCnn_model.predict(testX_scaled)
pred = np.argmax(pred, axis=-1)

# 혼동 행렬 및 정확도 출력
cm = confusion_matrix(testy, pred)
print("Confusion Matrix:\n", cm)
print("\nAccuracy:", accuracy_score(testy, pred))
print("\nClassification Report:\n", classification_report(testy, pred))

# 혼동 행렬 시각화
sns.heatmap(cm, annot=True, fmt='.2f', cmap='magma')
plt.title('Confusion Matrix - Simple CNN')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Confusion Matrix:
#  [[495   1   0   0   0   0]
#  [  0 463   7   1   0   0]
#  [  1   1 418   0   0   0]
#  [  0  20   0 407  59   5]
#  [  1   0   0  87 444   0]
#  [  0   0   0   0   0 537]]
#
# Accuracy: 0.9379029521547336
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       496
#            1       0.95      0.98      0.97       471
#            2       0.98      1.00      0.99       420
#            3       0.82      0.83      0.83       491
#            4       0.88      0.83      0.86       532
#            5       0.99      1.00      1.00       537
#
#     accuracy                           0.94      2947
#    macro avg       0.94      0.94      0.94      2947
# weighted avg       0.94      0.94      0.94      2947

# %%
# -----------------------------
# 7) 5-Fold 교차 검증
# -----------------------------

print("\n===== 5-Fold Cross Validation (Simple CNN) =====")

# 전체 train 세트 사용
X_all         = trainX_scaled              # 전체 학습 입력
y_all_int     = trainy.flatten()           # 정수 라벨 (0~5)
y_all_one_hot = trainy_one_hot             # 원-핫 라벨

# 폴드 분할 설정 (라벨 비율 유지)
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# 교차 검증용 모델 생성 함수 (위에서 쓴 튜닝된 Simple CNN과 동일 구조)
def create_simpleCnn_model():
    model = Sequential([
        Conv1D(128, kernel_size=5, activation='relu', padding='same',
               input_shape=(n_timesteps, n_features)),
        BatchNormalization(),
        Conv1D(128, kernel_size=5, activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.3),

        Conv1D(256, kernel_size=3, activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.3),

        Flatten(),
        Dense(256, activation='relu'),
        Dropout(0.5),
        Dense(n_outputs, activation='softmax')
    ])
    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )
    return model

fold_no = 1
cv_acc_list = []

for train_idx, val_idx in kfold.split(X_all, y_all_int):
    print(f"\n▶ Fold {fold_no}")

    # 폴드별 train / val 나누기
    X_tr, X_vl = X_all[train_idx], X_all[val_idx]
    y_tr, y_vl = y_all_one_hot[train_idx], y_all_one_hot[val_idx]

    # 폴드마다 새로운 모델 생성
    model_cv = create_simpleCnn_model()

    # 학습 (조금 줄여서 20 epoch 정도)
    history_cv = model_cv.fit(
        X_tr, y_tr,
        epochs=20,
        batch_size=64,
        validation_data=(X_vl, y_vl),
        verbose=0
    )

    # 검증 성능 평가
    loss_cv, acc_cv = model_cv.evaluate(X_vl, y_vl, verbose=0)
    print(f"Fold {fold_no} - val_loss: {loss_cv:.4f}, val_acc: {acc_cv:.4f}")

    cv_acc_list.append(acc_cv)
    fold_no += 1

print("\n===== Cross Validation Result (Simple CNN) =====")
print("Fold Accuracies:", [f"{a:.4f}" for a in cv_acc_list])
print(f"Mean Accuracy: {np.mean(cv_acc_list):.4f} ± {np.std(cv_acc_list):.4f}")
# Out:
# ===== 5-Fold Cross Validation (Simple CNN) =====
#
# ▶ Fold 1
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Fold 1 - val_loss: 0.0849, val_acc: 0.9545
#
# ▶ Fold 2
# Fold 2 - val_loss: 0.0912, val_acc: 0.9592
#
# ▶ Fold 3
# Fold 3 - val_loss: 0.1229, val_acc: 0.9605
#
# ▶ Fold 4
# Fold 4 - val_loss: 0.1357, val_acc: 0.9510
#
# ▶ Fold 5
# Fold 5 - val_loss: 0.0931, val_acc: 0.9612
#
# ===== Cross Validation Result (Simple CNN) =====
# Fold Accuracies: ['0.9545', '0.9592', '0.9605', '0.9510', '0.9612']
# Mean Accuracy: 0.9573 ± 0.0039
