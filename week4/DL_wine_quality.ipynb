# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

from tensorflow.keras import models, layers
from tensorflow.keras.utils import to_categorical

from sklearn.metrics import classification_report,confusion_matrix

# -----------------------------
# 1) 데이터 불러오기 및 통합
# -----------------------------

# 와인 데이터셋은 반드시 sep=";" 옵션을 지정해야 올바르게 열이 분리됨
red_wine  = pd.read_csv("/content/drive/MyDrive/ml-programming-lab/week4/winequality-red.csv",   sep=";")
white_wine= pd.read_csv("/content/drive/MyDrive/ml-programming-lab/week4/winequality-white.csv", sep=";")

# 와인 종류를 구분하기 위해 'type' 열을 추가
red_wine["type"]  = "red"
white_wine["type"]= "white"

# 레드 와인과 화이트 와인 데이터를 하나로 통합
wine_data = pd.concat([red_wine, white_wine], ignore_index=True)

# %%
wine_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality   type
# 0         9.4        5    red
# 1         9.8        5    red
# 2         9.8        5    red
# 3         9.8        6    red
# 4         9.4        5    red
# ...       ...      ...    ...
# 6492     11.2        6  white
# 6493      9.6        5  white
# 6494      9.4        6  white
# 6495     12.8        7  white
# 6496     11.8        6  white
#
# [6497 rows x 13 columns]

# %%
# quality에 어떤 값들이 있는지 확인
print("quality 종류:", wine_data['quality'].unique())
# Out:
# quality 종류: [5 6 7 4 8 3 9]

# %%
# -----------------------------
# 2) 결측치 확인
# -----------------------------

wine_data.isnull().sum()

# -----------------------------
# 3) 결측치 제거
# -----------------------------

wine_data = wine_data.dropna()
wine_data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# type                    0
# dtype: int64

# %%
# -----------------------------
# 4) 특징(X)과 타겟(y) 분리
# -----------------------------

X = wine_data.drop(columns=['quality'])

# 타겟은 와인 품질 점수 (quality)
y = wine_data['quality']

# %%
# -----------------------------
# 5) 라벨 인코딩
# -----------------------------

# 'type'은 문자열(red/white)이므로 숫자(0/1)로 변환
le = LabelEncoder()
X['type'] = le.fit_transform(X['type'])

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  type
# 0         9.4     0
# 1         9.8     0
# 2         9.8     0
# 3         9.8     0
# 4         9.4     0
# ...       ...   ...
# 6492     11.2     1
# 6493      9.6     1
# 6494      9.4     1
# 6495     12.8     1
# 6496     11.8     1
#
# [6497 rows x 12 columns]

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 6492    6
# 6493    5
# 6494    6
# 6495    7
# 6496    6
# Name: quality, Length: 6497, dtype: int64

# %%
# -----------------------------
# 6) 데이터 스케일링
# -----------------------------

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# -----------------------------
# 7) 타겟 변수 원-핫 인코딩
# -----------------------------

Y = pd.get_dummies(y).values

# %%
# -----------------------------
# 8) 훈련 데이터와 테스트 데이터 분리
# -----------------------------

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
# -----------------------------
# 9) 딥러닝 모델 구성 (Dropout 레이어 제외)
# -----------------------------

model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X.shape[1],)),
    layers.Dense(32, activation="relu"),
    layers.Dense(Y.shape[1], activation="softmax")  # 출력층 노드 수는 클래스의 개수와 동일
])

# 모델 요약 정보 출력
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,143 (12.28 KB)
#  Trainable params: 3,143 (12.28 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# -----------------------------
# 10) 모델 컴파일
# -----------------------------

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",  # 원-핫 인코딩된 다중 분류 문제에 사용
    metrics=["accuracy"]
)

# %%
# -----------------------------
# 11) 모델 학습
# -----------------------------

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3852 - loss: 1.5153 - val_accuracy: 0.5452 - val_loss: 1.1224
# Epoch 2/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5534 - loss: 1.0882 - val_accuracy: 0.5577 - val_loss: 1.0833
# Epoch 3/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5674 - loss: 1.0465 - val_accuracy: 0.5692 - val_loss: 1.0570
# Epoch 4/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5702 - loss: 1.0341 - val_accuracy: 0.5779 - val_loss: 1.0554
# Epoch 5/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5878 - loss: 1.0116 - val_accuracy: 0.5596 - val_loss: 1.0574
# Epoch 6/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5663 - loss: 1.0085 - val_accuracy: 0.5673 - val_loss: 1.0357
# Epoch 7/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5801 - loss: 1.0099 - val_accuracy: 0.5721 - val_loss: 1.0334
# Epoch 8/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5808 - loss: 0.9963 - val_accuracy: 0.5702 - val_loss: 1.0290
# Epoch 9/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5793 - loss: 0.9860 - val_accuracy: 0.5731 - val_loss: 1.0316
# Epoch 10/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5837 - loss: 0.9848 - val_accuracy: 0.5702 - val_loss: 1.0214
# Epoch 11/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5787 - loss: 0.9711 - val_accuracy: 0.5808 - val_loss: 1.0248
# Epoch 12/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5954 - loss: 0.9632 - val_accuracy: 0.5721 - val_loss: 1.0172
# Epoch 13/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6117 - loss: 0.9435 - val_accuracy: 0.5654 - val_loss: 1.0277
# Epoch 14/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5942 - loss: 0.9469 - val_accuracy: 0.5788 - val_loss: 1.0322
# Epoch 15/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6233 - loss: 0.9260 - val_accuracy: 0.5731 - val_loss: 1.0175
# Epoch 16/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6067 - loss: 0.9307 - val_accuracy: 0.5712 - val_loss: 1.0206
# Epoch 17/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6106 - loss: 0.9230 - val_accuracy: 0.5731 - val_loss: 1.0175
# Epoch 18/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6048 - loss: 0.9121 - val_accuracy: 0.5702 - val_loss: 1.0239
# Epoch 19/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5929 - loss: 0.9484 - val_accuracy: 0.5712 - val_loss: 1.0284
# Epoch 20/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6059 - loss: 0.9233 - val_accuracy: 0.5721 - val_loss: 1.0269
# Epoch 21/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6045 - loss: 0.9201 - val_accuracy: 0.5740 - val_loss: 1.0310
# Epoch 22/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6181 - loss: 0.9230 - val_accuracy: 0.5788 - val_loss: 1.0177
# Epoch 23/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6187 - loss: 0.9245 - val_accuracy: 0.5846 - val_loss: 1.0283
# Epoch 24/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6160 - loss: 0.8997 - val_accuracy: 0.5577 - val_loss: 1.0290
# Epoch 25/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6371 - loss: 0.8834 - val_accuracy: 0.5663 - val_loss: 1.0381
# Epoch 26/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6355 - loss: 0.8765 - val_accuracy: 0.5740 - val_loss: 1.0283
# Epoch 27/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6300 - loss: 0.8966 - val_accuracy: 0.5712 - val_loss: 1.0223
# Epoch 28/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6211 - loss: 0.8865 - val_accuracy: 0.5481 - val_loss: 1.0505
# Epoch 29/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6413 - loss: 0.8672 - val_accuracy: 0.5606 - val_loss: 1.0366
# Epoch 30/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6315 - loss: 0.8622 - val_accuracy: 0.5933 - val_loss: 1.0311
# Epoch 31/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6243 - loss: 0.8843 - val_accuracy: 0.5731 - val_loss: 1.0420
# Epoch 32/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6404 - loss: 0.8539 - val_accuracy: 0.5702 - val_loss: 1.0397
# Epoch 33/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6282 - loss: 0.8883 - val_accuracy: 0.5740 - val_loss: 1.0321
# Epoch 34/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6399 - loss: 0.8476 - val_accuracy: 0.5808 - val_loss: 1.0353
# Epoch 35/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6352 - loss: 0.8563 - val_accuracy: 0.5683 - val_loss: 1.0486
# Epoch 36/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6426 - loss: 0.8618 - val_accuracy: 0.5625 - val_loss: 1.0467
# Epoch 37/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6435 - loss: 0.8645 - val_accuracy: 0.5827 - val_loss: 1.0444
# Epoch 38/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6467 - loss: 0.8404 - val_accuracy: 0.5558 - val_loss: 1.0551
# Epoch 39/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6448 - loss: 0.8433 - val_accuracy: 0.5644 - val_loss: 1.0560
# Epoch 40/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6437 - loss: 0.8462 - val_accuracy: 0.5875 - val_loss: 1.0466
# Epoch 41/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6452 - loss: 0.8427 - val_accuracy: 0.5721 - val_loss: 1.0462
# Epoch 42/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6629 - loss: 0.8048 - val_accuracy: 0.5558 - val_loss: 1.0532
# Epoch 43/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6527 - loss: 0.8403 - val_accuracy: 0.5885 - val_loss: 1.0377
# Epoch 44/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6380 - loss: 0.8302 - val_accuracy: 0.5740 - val_loss: 1.0572
# Epoch 45/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6501 - loss: 0.8290 - val_accuracy: 0.5712 - val_loss: 1.0800
# Epoch 46/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6461 - loss: 0.8410 - val_accuracy: 0.5750 - val_loss: 1.0647
# Epoch 47/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6593 - loss: 0.8229 - val_accuracy: 0.5673 - val_loss: 1.0601
# Epoch 48/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6508 - loss: 0.8260 - val_accuracy: 0.5712 - val_loss: 1.0596
# Epoch 49/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6689 - loss: 0.8051 - val_accuracy: 0.5702 - val_loss: 1.0685
# Epoch 50/50
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6641 - loss: 0.8035 - val_accuracy: 0.5596 - val_loss: 1.0772

# %%
# -----------------------------
# 12) 모델 예측
# -----------------------------

# 테스트 데이터로 예측 수행
y_pred = model.predict(X_test)

# 원-핫 인코딩된 결과를 단일 클래스 레이블로 변환
y_test_class = np.argmax(y_test, axis=1)
y_pred_class = np.argmax(y_pred, axis=1)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# -----------------------------
# 13) 모델 평가
# -----------------------------

print("\n< Classification Report >")
print(classification_report(y_test_class,y_pred_class))

print("< Confusion Matrix (rows=true, cols=pred) >")
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# < Classification Report >
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         7
#            1       0.14      0.02      0.04        48
#            2       0.62      0.59      0.61       413
#            3       0.56      0.75      0.65       579
#            4       0.54      0.30      0.39       211
#            5       0.50      0.07      0.13        41
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.58      1300
#    macro avg       0.34      0.25      0.26      1300
# weighted avg       0.56      0.58      0.55      1300
#
# < Confusion Matrix (rows=true, cols=pred) >
# [[  0   2   5   0   0   0   0]
#  [  0   1  31  16   0   0   0]
#  [  0   3 245 161   4   0   0]
#  [  0   1 106 437  34   1   0]
#  [  0   0   8 138  63   2   0]
#  [  0   0   0  23  15   3   0]
#  [  0   0   0   1   0   0   0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
