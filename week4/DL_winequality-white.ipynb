# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

from tensorflow.keras import models, layers
from tensorflow.keras.utils import to_categorical

from sklearn.metrics import classification_report,confusion_matrix

# -----------------------------
# 1) 데이터 불러오기
# -----------------------------

# 와인 데이터셋은 반드시 sep=";" 옵션을 지정해야 올바르게 열이 분리됨
df= pd.read_csv("/content/drive/MyDrive/ml-programming-lab/week4/winequality-white.csv", sep=";")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
# quality에 어떤 값들이 있는지 확인
print("quality 종류:", df['quality'].unique())
# Out:
# quality 종류: [6 5 7 8 4 3 9]

# %%
# -----------------------------
# 2) 결측치 확인
# -----------------------------

df.isnull().sum()

# -----------------------------
# 3) 결측치 제거
# -----------------------------

df = df.dropna()
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# -----------------------------
# 4) 특징(X)과 타겟(y) 분리
# -----------------------------

X = df.drop(columns=['quality'])

# 타겟은 와인 품질 점수 (quality)
y = df['quality']

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol
# 0         8.8
# 1         9.5
# 2        10.1
# 3         9.9
# 4         9.9
# ...       ...
# 4893     11.2
# 4894      9.6
# 4895      9.4
# 4896     12.8
# 4897     11.8
#
# [4898 rows x 11 columns]

# %%
y
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 4893    6
# 4894    5
# 4895    6
# 4896    7
# 4897    6
# Name: quality, Length: 4898, dtype: int64

# %%
# -----------------------------
# 5) 데이터 스케일링
# -----------------------------

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# -----------------------------
# 6) 타겟 변수 원-핫 인코딩
# -----------------------------

Y = pd.get_dummies(y).values

# %%
# -----------------------------
# 7) 훈련 데이터와 테스트 데이터 분리
# -----------------------------

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
# -----------------------------
# 8) 딥러닝 모델 구성 (Dropout 레이어 제외)
# -----------------------------

model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X.shape[1],)),
    layers.Dense(32, activation="relu"),
    layers.Dense(Y.shape[1], activation="softmax")  # 출력층 노드 수는 클래스의 개수와 동일
])

# 모델 요약 정보 출력
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,079 (12.03 KB)
#  Trainable params: 3,079 (12.03 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# -----------------------------
# 9) 모델 컴파일
# -----------------------------

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",  # 원-핫 인코딩된 다중 분류 문제에 사용
    metrics=["accuracy"]
)

# %%
# -----------------------------
# 10) 모델 학습
# -----------------------------

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4131 - loss: 1.5311 - val_accuracy: 0.5510 - val_loss: 1.1267
# Epoch 2/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5542 - loss: 1.1105 - val_accuracy: 0.5497 - val_loss: 1.0703
# Epoch 3/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5572 - loss: 1.0719 - val_accuracy: 0.5625 - val_loss: 1.0410
# Epoch 4/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5841 - loss: 1.0045 - val_accuracy: 0.5446 - val_loss: 1.0441
# Epoch 5/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5719 - loss: 1.0164 - val_accuracy: 0.5676 - val_loss: 1.0248
# Epoch 6/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5970 - loss: 0.9687 - val_accuracy: 0.5676 - val_loss: 1.0222
# Epoch 7/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5859 - loss: 0.9936 - val_accuracy: 0.5548 - val_loss: 1.0222
# Epoch 8/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5937 - loss: 0.9714 - val_accuracy: 0.5599 - val_loss: 1.0089
# Epoch 9/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5927 - loss: 0.9664 - val_accuracy: 0.5663 - val_loss: 1.0075
# Epoch 10/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6086 - loss: 0.9260 - val_accuracy: 0.5676 - val_loss: 1.0002
# Epoch 11/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6007 - loss: 0.9568 - val_accuracy: 0.5625 - val_loss: 1.0011
# Epoch 12/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5975 - loss: 0.9670 - val_accuracy: 0.5574 - val_loss: 0.9991
# Epoch 13/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5823 - loss: 0.9578 - val_accuracy: 0.5791 - val_loss: 0.9990
# Epoch 14/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5991 - loss: 0.9406 - val_accuracy: 0.5663 - val_loss: 1.0106
# Epoch 15/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6130 - loss: 0.9108 - val_accuracy: 0.5625 - val_loss: 1.0008
# Epoch 16/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6120 - loss: 0.9165 - val_accuracy: 0.5765 - val_loss: 0.9933
# Epoch 17/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6233 - loss: 0.8960 - val_accuracy: 0.5753 - val_loss: 0.9947
# Epoch 18/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6302 - loss: 0.8985 - val_accuracy: 0.5918 - val_loss: 0.9898
# Epoch 19/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6191 - loss: 0.9031 - val_accuracy: 0.5816 - val_loss: 1.0054
# Epoch 20/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6310 - loss: 0.8935 - val_accuracy: 0.5561 - val_loss: 1.0408
# Epoch 21/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6211 - loss: 0.8939 - val_accuracy: 0.5587 - val_loss: 1.0123
# Epoch 22/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6188 - loss: 0.8904 - val_accuracy: 0.5765 - val_loss: 0.9946
# Epoch 23/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6300 - loss: 0.8646 - val_accuracy: 0.5676 - val_loss: 1.0241
# Epoch 24/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6296 - loss: 0.8925 - val_accuracy: 0.5727 - val_loss: 0.9976
# Epoch 25/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6504 - loss: 0.8602 - val_accuracy: 0.5842 - val_loss: 1.0089
# Epoch 26/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6332 - loss: 0.8715 - val_accuracy: 0.5765 - val_loss: 0.9990
# Epoch 27/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6539 - loss: 0.8304 - val_accuracy: 0.5702 - val_loss: 1.0139
# Epoch 28/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6398 - loss: 0.8592 - val_accuracy: 0.5829 - val_loss: 0.9940
# Epoch 29/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6513 - loss: 0.8379 - val_accuracy: 0.5599 - val_loss: 1.0236
# Epoch 30/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6446 - loss: 0.8395 - val_accuracy: 0.5663 - val_loss: 1.0115
# Epoch 31/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6447 - loss: 0.8327 - val_accuracy: 0.5816 - val_loss: 1.0163
# Epoch 32/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6507 - loss: 0.8239 - val_accuracy: 0.5842 - val_loss: 1.0103
# Epoch 33/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6539 - loss: 0.8053 - val_accuracy: 0.5676 - val_loss: 1.0240
# Epoch 34/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6576 - loss: 0.8193 - val_accuracy: 0.5791 - val_loss: 1.0307
# Epoch 35/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6587 - loss: 0.8299 - val_accuracy: 0.5702 - val_loss: 1.0309
# Epoch 36/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6700 - loss: 0.7955 - val_accuracy: 0.5638 - val_loss: 1.0311
# Epoch 37/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6713 - loss: 0.8127 - val_accuracy: 0.5842 - val_loss: 1.0174
# Epoch 38/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6612 - loss: 0.8026 - val_accuracy: 0.5804 - val_loss: 1.0224
# Epoch 39/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6567 - loss: 0.8051 - val_accuracy: 0.5727 - val_loss: 1.0404
# Epoch 40/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6734 - loss: 0.8001 - val_accuracy: 0.5727 - val_loss: 1.0387
# Epoch 41/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6642 - loss: 0.8095 - val_accuracy: 0.5702 - val_loss: 1.0283
# Epoch 42/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6706 - loss: 0.8097 - val_accuracy: 0.5867 - val_loss: 1.0379
# Epoch 43/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6874 - loss: 0.7730 - val_accuracy: 0.5880 - val_loss: 1.0403
# Epoch 44/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6726 - loss: 0.7996 - val_accuracy: 0.5867 - val_loss: 1.0352
# Epoch 45/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6877 - loss: 0.7572 - val_accuracy: 0.5791 - val_loss: 1.0479
# Epoch 46/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6934 - loss: 0.7556 - val_accuracy: 0.5778 - val_loss: 1.0388
# Epoch 47/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6876 - loss: 0.7693 - val_accuracy: 0.5765 - val_loss: 1.0337
# Epoch 48/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6902 - loss: 0.7559 - val_accuracy: 0.5740 - val_loss: 1.0465
# Epoch 49/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6886 - loss: 0.7536 - val_accuracy: 0.5638 - val_loss: 1.0471
# Epoch 50/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6917 - loss: 0.7541 - val_accuracy: 0.5778 - val_loss: 1.0625

# %%
# -----------------------------
# 11) 모델 예측
# -----------------------------

# 테스트 데이터로 예측 수행
y_pred = model.predict(X_test)

# 원-핫 인코딩된 결과를 단일 클래스 레이블로 변환
y_test_class = np.argmax(y_test, axis=1)
y_pred_class = np.argmax(y_pred, axis=1)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# -----------------------------
# 12) 모델 평가
# -----------------------------

print("\n< Classification Report >")
print(classification_report(y_test_class,y_pred_class))

print("< Confusion Matrix (rows=true, cols=pred) >")
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# < Classification Report >
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         9
#            1       0.71      0.20      0.31        51
#            2       0.61      0.51      0.56       295
#            3       0.51      0.76      0.61       409
#            4       0.53      0.31      0.39       183
#            5       0.20      0.03      0.05        33
#
#     accuracy                           0.54       980
#    macro avg       0.43      0.30      0.32       980
# weighted avg       0.54      0.54      0.51       980
#
# < Confusion Matrix (rows=true, cols=pred) >
# [[  0   1   4   4   0   0]
#  [  0  10  24  15   2   0]
#  [  0   2 151 140   2   0]
#  [  1   1  61 312  33   1]
#  [  0   0   8 116  56   3]
#  [  0   0   0  19  13   1]]
